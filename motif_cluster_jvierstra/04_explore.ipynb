# %%
source ./config.sh -v
# Out:
# You are on Duke Server: HARDAC
# BASE DIRECTORY:     /gpfs/fs1/data/reddylab/Kuei
# PATH OF SOURCE:     /gpfs/fs1/data/reddylab/Kuei/source
# PATH OF EXECUTABLE: /gpfs/fs1/data/reddylab/Kuei/exe
# PATH OF ANNOTATION: /gpfs/fs1/data/reddylab/Kuei/annotation
# PATH OF PROJECT:    /gpfs/fs1/data/reddylab/Kuei/GitRepo/Settool_Bio
# PATH OF LOG:        /gpfs/fs1/data/reddylab/Kuei/annotation/log

# %%
echo ${FD_RES}
echo +++++++++++++++++++++++++++++++++++++
ls ${FD_RES}
echo +++++++++++++++++++++++++++++++++++++
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/{chr?.bed.gz,chr??.bed.gz}); do
    echo $(basename ${FPATH})
done
echo +++++++++++++++++++++++++++++++++++++
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/{chr?_rm_mouse.bed.gz,chr??_rm_mouse.bed.gz}); do
    echo $(basename ${FPATH})
done
echo +++++++++++++++++++++++++++++++++++++
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/{chr?_rm_mouse_merge.bed.gz,chr??_rm_mouse_merge.bed.gz}); do
    echo $(basename ${FPATH})
done
# Out:
# /gpfs/fs1/data/reddylab/Kuei/annotation/motif_cluster_jvierstra
# +++++++++++++++++++++++++++++++++++++
# hg38_all_motifs_chroms.txt                 hg38_archetype_motifs_v1
# hg38_all_motifs_v1                         motif_score_histogram.pickle
# hg38_archetype_motifs_chroms.txt           motif_score_histogram.tsv
# hg38_archetype_motifs_clusters_reduce.txt
# +++++++++++++++++++++++++++++++++++++
# chr10.bed.gz
# chr11.bed.gz
# chr12.bed.gz
# chr13.bed.gz
# chr14.bed.gz
# chr15.bed.gz
# chr16.bed.gz
# chr17.bed.gz
# chr18.bed.gz
# chr19.bed.gz
# chr1.bed.gz
# chr20.bed.gz
# chr21.bed.gz
# chr22.bed.gz
# chr2.bed.gz
# chr3.bed.gz
# chr4.bed.gz
# chr5.bed.gz
# chr6.bed.gz
# chr7.bed.gz
# chr8.bed.gz
# chr9.bed.gz
# chrM.bed.gz
# chrX.bed.gz
# chrY.bed.gz
# +++++++++++++++++++++++++++++++++++++
# chr10_rm_mouse.bed.gz
# chr11_rm_mouse.bed.gz
# chr12_rm_mouse.bed.gz
# chr13_rm_mouse.bed.gz
# chr14_rm_mouse.bed.gz
# chr15_rm_mouse.bed.gz
# chr16_rm_mouse.bed.gz
# chr17_rm_mouse.bed.gz
# ...

# %%
head ${FD_RES}/hg38_archetype_motifs_v1/chr17/clusters.txt
# Out:
# AHR
# AIRE
# AP1/1
# AP1/2
# ARI5A
# ARI5B
# BATF
# BCL6/1
# BCL6/2
# CCAAT/CEBP

# %%
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/chrX/*_merge.bed); do
    NLINE=$(cat ${FPATH} | wc -l)
    FNAME=$(basename ${FPATH})
    printf "%+7s  %s\n" ${NLINE} ${FNAME}
done
# Out:
#   22178  AHR_merge.bed
#   31554  AIRE_merge.bed
#  131085  AP1_1_merge.bed
#  115554  AP1_2_merge.bed
#   21498  ARI5A_merge.bed
#   26573  ARI5B_merge.bed
#   62066  BATF_merge.bed
#    6065  BCL6_1_merge.bed
#   47366  BCL6_2_merge.bed
#   85607  CCAAT_CEBP_merge.bed
#   18987  CENBP_merge.bed
#   86933  CPEB1_merge.bed
#   47604  CREB3_XBP1_merge.bed
#   87446  CREB_ATF_1_merge.bed
#   51540  CREB_ATF_2_merge.bed
#   18574  CREB_ATF_3_merge.bed
#  151755  CTCF_merge.bed
#   63668  CUX_1_merge.bed
#   27380  CUX_2_merge.bed
#    8939  CUX_3_merge.bed
#   43276  DDIT3+CEBPA_merge.bed
#   24271  DMRT3_merge.bed
#   70681  E2F_1_merge.bed
#  235896  E2F_2_merge.bed
#   38193  E2F_3_merge.bed
#   18241  E2F_4_merge.bed
#   71625  EBF1_merge.bed
#  194024  Ebox_CACCTG_merge.bed
#  180170  Ebox_CACGTG_1_merge.bed
#  152601  Ebox_CACGTG_2_merge.bed
#  262501  Ebox_CAGATGG_merge.bed
#  316900  Ebox_CAGCTG_merge.bed
#   85928  Ebox_CATATG_merge.bed
#   75580  EGR_merge.bed
# ...

# %%
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/chrY/*_merge.bed); do
    NLINE=$(cat ${FPATH} | wc -l)
    FNAME=$(basename ${FPATH})
    printf "%+7s  %s\n" ${NLINE} ${FNAME}
done
# Out:
#    2663  AHR_merge.bed
#    4783  AIRE_merge.bed
#   20392  AP1_1_merge.bed
#   17431  AP1_2_merge.bed
#    3055  ARI5A_merge.bed
#    4318  ARI5B_merge.bed
#    9043  BATF_merge.bed
#     829  BCL6_1_merge.bed
#    7126  BCL6_2_merge.bed
#   14380  CCAAT_CEBP_merge.bed
#     955  CENBP_merge.bed
#   13189  CPEB1_merge.bed
#    7193  CREB3_XBP1_merge.bed
#   14512  CREB_ATF_1_merge.bed
#    8326  CREB_ATF_2_merge.bed
#    3379  CREB_ATF_3_merge.bed
#   22045  CTCF_merge.bed
#    9033  CUX_1_merge.bed
#    4171  CUX_2_merge.bed
#    1385  CUX_3_merge.bed
#    5969  DDIT3+CEBPA_merge.bed
#    3655  DMRT3_merge.bed
#   11270  E2F_1_merge.bed
#   28330  E2F_2_merge.bed
#    5371  E2F_3_merge.bed
#    2350  E2F_4_merge.bed
#   10989  EBF1_merge.bed
#   32320  Ebox_CACCTG_merge.bed
#   25675  Ebox_CACGTG_1_merge.bed
#   21990  Ebox_CACGTG_2_merge.bed
#   40346  Ebox_CAGATGG_merge.bed
#   49626  Ebox_CAGCTG_merge.bed
#   13783  Ebox_CATATG_merge.bed
#    9429  EGR_merge.bed
# ...

# %%
for FPATH in $(ls ${FD_RES}/hg38_archetype_motifs_v1/chr17/*_merge.bed); do
    NLINE=$(cat ${FPATH} | wc -l)
    FNAME=$(basename ${FPATH})
    printf "%+7s  %s\n" ${NLINE} ${FNAME}
done
# Out:
#   11573  AHR_merge.bed
#   15287  AIRE_merge.bed
#   90233  AP1_1_merge.bed
#   85741  AP1_2_merge.bed
#   11466  ARI5A_merge.bed
#   11965  ARI5B_merge.bed
#   34172  BATF_merge.bed
#    2779  BCL6_1_merge.bed
#   25319  BCL6_2_merge.bed
#   48188  CCAAT_CEBP_merge.bed
#   18151  CENBP_merge.bed
#   57866  CPEB1_merge.bed
#   29297  CREB3_XBP1_merge.bed
#   51678  CREB_ATF_1_merge.bed
#   27865  CREB_ATF_2_merge.bed
#    9865  CREB_ATF_3_merge.bed
#   87220  CTCF_merge.bed
#   34296  CUX_1_merge.bed
#   12001  CUX_2_merge.bed
#    3886  CUX_3_merge.bed
#   24421  DDIT3+CEBPA_merge.bed
#   10770  DMRT3_merge.bed
#   32997  E2F_1_merge.bed
#  148076  E2F_2_merge.bed
#   18082  E2F_3_merge.bed
#    8677  E2F_4_merge.bed
#   35874  EBF1_merge.bed
#  103302  Ebox_CACCTG_merge.bed
#   86734  Ebox_CACGTG_1_merge.bed
#   76588  Ebox_CACGTG_2_merge.bed
#  153295  Ebox_CAGATGG_merge.bed
#  170139  Ebox_CAGCTG_merge.bed
#   38855  Ebox_CATATG_merge.bed
#   41810  EGR_merge.bed
# ...
