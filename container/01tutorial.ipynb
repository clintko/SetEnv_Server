# %%
ls
# Out:
# download_container.ipynb

# %%
pwd
# Out:
# /gpfs/fs1/data/reddylab/Kuei/GitRepo/Settool_Bio/container

# %%
singularity pull docker://quay.io/biocontainers/salmon:1.2.1--hf69c8f4_0
# Out:
# INFO:    Converting OCI blobs to SIF format
# INFO:    Starting build...
# Getting image source signatures
# Copying blob a3ed95caeb02 [======================================] 32.0b / 32.0b
# Copying blob a3ed95caeb02 done
# Copying blob a3ed95caeb02 done
# Copying blob a3ed95caeb02 done
# Copying blob a3ed95caeb02 done
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 [====================================] 2.1MiB / 2.1MiB
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob 3aaade50789a [====================================] 247.0b / 247.0b
# Copying blob a3ed95caeb02 done
# Copying blob 77c6c00e8b61 done
# Copying blob 3aaade50789a done
# Copying blob a3ed95caeb02 done
# ...

# %%
singularity cache list -v
# Out:
# NAME                     DATE CREATED           SIZE             TYPE
# 00cf8b9f3d2a0874563583   2022-09-21 11:25:09    0.21 KiB         blob
# 10c3bb32200bdb5006b484   2022-09-21 11:25:10    853.21 KiB       blob
# 1678a725ed4726fc6f95ab   2022-09-05 16:12:08    562.88 MiB       blob
# 1868e28f94a944cd5d9bb5   2022-09-05 16:36:44    207.99 MiB       blob
# 2707b2c1cab76cde52e37d   2022-09-05 16:11:49    1.68 KiB         blob
# 36dd5cf718e70b57a7b8c9   2022-09-05 16:11:53    36.19 MiB        blob
# 3aaade50789a6510c60e53   2022-09-21 11:25:09    0.24 KiB         blob
# 3b65ec22a9e96affe68071   2022-09-05 16:11:49    27.25 MiB        blob
# 41c9cc3a56903a2c2de2a0   2022-09-05 16:11:57    223.13 MiB       blob
# 4970ff4998a5ab9fad4baf   2022-09-21 11:25:11    45.87 MiB        blob
# 4e941c18fe51dfffa6842f   2022-09-05 16:11:52    246.35 MiB       blob
# 6650d605aa720065943299   2022-09-05 16:36:44    25.92 KiB        blob
# ...

# %%
ls salmon*
# Out:
# salmon_1.2.1--hf69c8f4_0.sif

# %%
singularity run salmon_1.2.1--hf69c8f4_0.sif ls
# Out:
# WARNING: Skipping mount /var/singularity/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
# Kuei              bin               reddylab
# R                 config            scratch
# Rlibs             module_avail.txt  tmp

# %%
singularity exec salmon_1.2.1--hf69c8f4_0.sif salmon --help
# Out:
# WARNING: Skipping mount /var/singularity/mnt/session/etc/resolv.conf [files]: /etc/resolv.conf doesn't exist in container
# salmon v1.2.1
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index Create a salmon index
#      quant Quantify a sample
#      alevin single cell analysis
#      swim  Perform super-secret operation
#      quantmerge Merge multiple quantifications into a single file
